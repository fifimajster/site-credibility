# %%
import dodgyness
import matplotlib as plt
# %matplotlib inline
# Out:
# /usr/local/lib/python3.4/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
siteNames = ['https://www.infowars.com',
             'http://www.bbc.com/news/']

sitesInfo = []
sitesInfo = dodgyness.mainInformationGatherer(siteNames, sitesInfo, 300)
# Out:
# You must `download()` an article before calling `parse()` on it!
# couldnt process article: https://www.infowars.com/ https://www.infowars.com/cnn-caught-staging-fake-news-scene/#disqus_thread
# processed article: https://www.infowars.com/putin-if-the-deep-state-can-kill-jfk-they-can-frame-russia-for-hacks/
# processed article: http://www.bbc.com/travel/gallery/20170428-stunning-locations-seen-from-space
# processed article: http://www.bbc.com/radio/help#contact

# %%
dodgyness.interpretInfo(sitesInfo)

# %%
dodgyness.compareArticleToOtherSites('http://thefreepatriot.org/while-world-whines-about-climate-trump-keeps-his-eye-on-real-threat-islamic-terror/',
                                     sitesInfo,
                                     bigrams=True)
# Out:
# processed article: http://thefreepatriot.org/while-world-whines-about-climate-trump-keeps-his-eye-on-real-threat-islamic-terror/
#
# classification according to OpenSources.co: fake, bias, clickbait, ,
#
# no authors found!
#
# keywords: ['trump', 'london', 'work', 'climate', 'eye', 'dead', 'keeps', 'attack', 'need', 'real', 'world', 'threat', 'islamic', 'united', 'whines', 'terror']
#
# https://www.infowars.com
# articles: 1 	words: 843 	sentences: 30 	emotions: 0.079 	attitude: -0.0265
# http://www.bbc.com/news/
# articles: 2 	words: 389 	sentences: 12 	emotions: 0.0321 	attitude: 0.0484
# http://thefreepatriot.org/while-world-whines-about-climate-trump-keeps-his-eye-on-real-threat-islamic-terror/
# articles: 1 	words: 608 	sentences: 27 	emotions: 0.1475 	attitude: -0.1745
#
# used words are most simiral to:   (in descending order)
# 1.8914 	 https://www.infowars.com
# 1.9506 	 http://www.bbc.com/news/
# ...
